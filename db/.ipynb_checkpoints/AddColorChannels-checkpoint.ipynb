# %%
import os, sys
import numpy as np
import psycopg2
from subprocess import call
import subprocess

# %%
# call(["convert", "-size", "100x100", "xc:wheat", "canvas_wheat.gif"])
# call(["convert", "-size", "100x100", "xc:red", "canvas_red.gif"])
# Out:
# 0

# %%
# set context/cwd

stack_folder = "/Users/OGN/1Projects/ZBrain2/app/assets/images/"
channel_folder = "/Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/"

os.chdir(stack_folder)
cwd = os.getcwd()
print "Current working directory %s" % cwd
# Out:
# Current working directory /Users/OGN/1Projects/ZBrain2/app/assets/images

# %%
# get stack names

stacks = os.listdir(stack_folder)
stacks = [ stack for stack in stacks if os.path.isdir(stack) ]
print stacks[:8]
# Out:
# ['6.7FRhcrtR-Gal4-uasKaede', 'Anti-5HT', 'Anti-Gad67', 'Anti-GlyR', 'Anti-tERK', 'Anti-TH', 'Anti-Zn1', 'Anti-Zn12(Hnk-1)']

# %%
# create color channel folders

colors = ['red', 'blue', 'green', 'cyan']

for stack in stacks:
    folder_path = "/Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/%s/" % stack
    try:
        os.mkdir(folder_path)
    except:
        pass
    for color in colors:
        channel_path = folder_path + color
        try:
            os.mkdir(channel_path)
        except:
            pass

# %%
# create color channel overlays for each stack

for s, stack in enumerate(stacks[28:]):
    src = "/Users/OGN/1Projects/ZBrain2/app/assets/images/%s/" % stack
    base = "/Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/%s/" % stack

    os.chdir(src)
    print s, base
    for color in colors:
        dest = base + color
        #call(["mogrify", "-path", dest, "+level-colors", "black,%s"%color, "-fuzz", "9%", "-transparent", "black", "*.png"]
        cwd = os.getcwd()
        print cwd
        try:
            subprocess.check_output(["mogrify", "-path", dest, "-format", "png", "+level-colors", "black,%s"%color, "-fuzz", "9%", "-transparent", "black", "*.jpg"], stderr=subprocess.STDOUT)
        except subprocess.CalledProcessError as err:
            print err.output
# Out:
# 0 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/6.7FRhcrtR-Gal4-uasKaede
# /Users/OGN/1Projects/ZBrain2/app/assets/images/6.7FRhcrtR-Gal4-uasKaede
# /Users/OGN/1Projects/ZBrain2/app/assets/images/6.7FRhcrtR-Gal4-uasKaede
# /Users/OGN/1Projects/ZBrain2/app/assets/images/6.7FRhcrtR-Gal4-uasKaede
# 1 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/Anti-5HT/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-5HT
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-5HT
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-5HT
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-5HT
# 2 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/Anti-Gad67/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-Gad67
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-Gad67
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-Gad67
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-Gad67
# 3 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/Anti-GlyR/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-GlyR
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-GlyR
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-GlyR
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-GlyR
# 4 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/Anti-tERK/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-tERK
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-tERK
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-tERK
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-tERK
# 5 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/Anti-TH/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-TH
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-TH
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-TH
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-TH
# 6 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/Anti-Zn1/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-Zn1
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-Zn1
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-Zn1
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-Zn1
# 7 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/Anti-Zn12(Hnk-1)/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-Zn12(Hnk-1)
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-Zn12(Hnk-1)
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-Zn12(Hnk-1)
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-Zn12(Hnk-1)
# 8 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/Anti-Znp1(Synaptotagmin2)/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-Znp1(Synaptotagmin2)
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-Znp1(Synaptotagmin2)
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-Znp1(Synaptotagmin2)
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-Znp1(Synaptotagmin2)
# 9 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/Anti-Zrf1(GFAP)/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-Zrf1(GFAP)
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-Zrf1(GFAP)
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-Zrf1(GFAP)
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-Zrf1(GFAP)
# 10 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/Anti-Zrf2/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-Zrf2
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-Zrf2
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-Zrf2
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Anti-Zrf2
# 11 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/Elavl3-GCaMP5G/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Elavl3-GCaMP5G
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Elavl3-GCaMP5G
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Elavl3-GCaMP5G
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Elavl3-GCaMP5G
# 12 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/Elavl3-H2BRFP/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Elavl3-H2BRFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Elavl3-H2BRFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Elavl3-H2BRFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Elavl3-H2BRFP
# 13 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/EtVmat2-GFP/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/EtVmat2-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/EtVmat2-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/EtVmat2-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/EtVmat2-GFP
# 14 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/Gad1b-GFP/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Gad1b-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Gad1b-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Gad1b-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Gad1b-GFP
# 15 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/Glyt2-GFP/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Glyt2-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Glyt2-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Glyt2-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Glyt2-GFP
# 16 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/Hcrt-RFP/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Hcrt-RFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Hcrt-RFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Hcrt-RFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Hcrt-RFP
# 17 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/Isl1-GFP/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Isl1-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Isl1-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Isl1-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Isl1-GFP
# 18 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/Isl2bGal4-uasDendra/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Isl2bGal4-uasDendra
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Isl2bGal4-uasDendra
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Isl2bGal4-uasDendra
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Isl2bGal4-uasDendra
# 19 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/Olig2-GFP/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Olig2-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Olig2-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Olig2-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Olig2-GFP
# 20 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/Otpb.A-Gal4-UAS-GCaMP/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Otpb.A-Gal4-UAS-GCaMP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Otpb.A-Gal4-UAS-GCaMP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Otpb.A-Gal4-UAS-GCaMP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Otpb.A-Gal4-UAS-GCaMP
# 21 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/Otpb.A-Nsfb-GFP/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Otpb.A-Nsfb-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Otpb.A-Nsfb-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Otpb.A-Nsfb-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Otpb.A-Nsfb-GFP
# 22 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/Oxtl-GFP/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Oxtl-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Oxtl-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Oxtl-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Oxtl-GFP
# 23 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/Pet1-GFP/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Pet1-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Pet1-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Pet1-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Pet1-GFP
# 24 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/Ptf1aGal4-uasKaede/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Ptf1aGal4-uasKaede
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Ptf1aGal4-uasKaede
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Ptf1aGal4-uasKaede
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Ptf1aGal4-uasKaede
# 25 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/Qrfp-GFP/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Qrfp-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Qrfp-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Qrfp-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Qrfp-GFP
# 26 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/S1181tGal4-uasKaede/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/S1181tGal4-uasKaede
# /Users/OGN/1Projects/ZBrain2/app/assets/images/S1181tGal4-uasKaede
# /Users/OGN/1Projects/ZBrain2/app/assets/images/S1181tGal4-uasKaede
# /Users/OGN/1Projects/ZBrain2/app/assets/images/S1181tGal4-uasKaede
# 27 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/SpinalBackfills/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/SpinalBackfills
# /Users/OGN/1Projects/ZBrain2/app/assets/images/SpinalBackfills
# /Users/OGN/1Projects/ZBrain2/app/assets/images/SpinalBackfills
# /Users/OGN/1Projects/ZBrain2/app/assets/images/SpinalBackfills
# 28 /Users/OGN/1Projects/ZBrain2/app/assets/3-ColorChannels/Vglut2a-GFP/
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Vglut2a-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Vglut2a-GFP
# /Users/OGN/1Projects/ZBrain2/app/assets/images/Vglut2a-GFP
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-f348399c245a> in <module>()
#      13         print cwd
#      14         try:
# ---> 15             subprocess.check_output(["mogrify", "-path", dest, "-format", "png", "+level-colors", "black,%s"%color, "-fuzz", "9%", "-transparent", "black", "*.jpg"], stderr=subprocess.STDOUT)
#      16         except subprocess.CalledProcessError as err:
#      17             print err.output
#
# /Users/OGN/anaconda/lib/python2.7/subprocess.pyc in check_output(*popenargs, **kwargs)
#     566         raise ValueError('stdout argument not allowed, it will be overridden.')
#     567     process = Popen(stdout=PIPE, *popenargs, **kwargs)
# --> 568     output, unused_err = process.communicate()
#     569     retcode = process.poll()
#     570     if retcode:
#
# /Users/OGN/anaconda/lib/python2.7/subprocess.pyc in communicate(self, input)
#     790                 self.stdin.close()
#     791             elif self.stdout:
# --> 792                 stdout = _eintr_retry_call(self.stdout.read)
#     793                 self.stdout.close()
#     794             elif self.stderr:
#
# /Users/OGN/anaconda/lib/python2.7/subprocess.pyc in _eintr_retry_call(func, *args)
#     474     while True:
#     475         try:
# --> 476             return func(*args)
#     477         except (OSError, IOError) as e:
#     478             if e.errno == errno.EINTR:
#
# KeyboardInterrupt:

# %%
# prepare postgreSQL table

create_table_command = (
"""
    DROP TABLE colorchannels;
    CREATE TABLE colorChannels (
        channel_id SERIAL PRIMARY KEY,
        channel_color TEXT NOT NULL,
        channel_name TEXT NOT NULL,
        channel_image_path TEXT NOT NULL
    );
""")

# %%
# connect to zbrain2db postgreSQL database

conn = psycopg2.connect(dbname='zbrain2db', user='gqe', host='localhost', password='')
cursor = conn.cursor()

# %%
# create table colorChannels

try:
    cursor.execute(create_table_command)
    cursor.close()
    conn.commit()
except (Exception, psycopg2.DatabaseError) as error:
    print error
finally:
    if conn is not None:
        conn.close()

# %%
from natsort import natsorted

# %%
# create array of table insert commands for each color channel image

channel_id = 0
insert_commands = []
for stack in stacks[3:]:
    src = "/Users/OGN/1Projects/ZBrain2/app/assets/imagesbk/%s/" % stack
    base = "/Users/OGN/1Projects/ZBrain2/app/assets/images/3-ColorChannels/%s/" % stack
    rel = "images/3-ColorChannels/%s/" % stack
    
    colors = ['red', 'blue', 'green', 'cyan']
    for color in colors:
        channel_folder = base + color
        channels = os.listdir(channel_folder)
        channels = [ "%s%s/%s" % (rel, color, channel) for channel in channels]
        channels = natsorted(channels)
        for channel_image_path in channels:
            insert_command = ("INSERT INTO colorChannels (channel_id, channel_color, channel_name, channel_image_path) values (%i, '%s', '%s', '%s')" 
                                 % (channel_id, color, stack, channel_image_path))
            channel_id += 1
            insert_commands.append(insert_command)

# %%
# use insert command array to create table entries for each color channel image

conn = psycopg2.connect(dbname='zbrain2db', user='gqe', host='localhost', password='')
cursor = conn.cursor()

for insert_command in insert_commands:
    try:
        cursor.execute(insert_command)
    except Exception, e:
        print repr(e)
        
cursor.close()
conn.commit()

# %%
conn = psycopg2.connect(dbname='zbrain2db', user='gqe', host='localhost', password='')
cursor = conn.cursor()
cursor.execute('SELECT * FROM colorChannels ORDER BY channel_id')

rows = cursor.fetchall()
for row in rows[300:500]:
    print row
# Out:
# (300, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-24.png')
# (301, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-25.png')
# (302, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-26.png')
# (303, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-27.png')
# (304, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-28.png')
# (305, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-29.png')
# (306, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-30.png')
# (307, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-31.png')
# (308, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-32.png')
# (309, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-33.png')
# (310, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-34.png')
# (311, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-35.png')
# (312, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-36.png')
# (313, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-37.png')
# (314, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-38.png')
# (315, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-39.png')
# (316, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-40.png')
# (317, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-41.png')
# (318, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-42.png')
# (319, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-43.png')
# (320, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-44.png')
# (321, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-45.png')
# (322, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-46.png')
# (323, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-47.png')
# (324, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-48.png')
# (325, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-49.png')
# (326, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-50.png')
# (327, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-51.png')
# (328, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-52.png')
# (329, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-53.png')
# (330, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-54.png')
# (331, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-55.png')
# (332, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-56.png')
# (333, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-57.png')
# (334, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-58.png')
# (335, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-59.png')
# (336, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-60.png')
# (337, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-61.png')
# (338, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-62.png')
# (339, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-63.png')
# (340, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-64.png')
# (341, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-65.png')
# (342, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-66.png')
# (343, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-67.png')
# (344, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-68.png')
# (345, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-69.png')
# (346, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-70.png')
# (347, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-71.png')
# (348, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-72.png')
# (349, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-73.png')
# (350, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-74.png')
# (351, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-75.png')
# (352, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-76.png')
# (353, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-77.png')
# (354, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-78.png')
# (355, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-79.png')
# (356, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-80.png')
# (357, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-81.png')
# (358, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-82.png')
# (359, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-83.png')
# (360, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-84.png')
# (361, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-85.png')
# (362, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-86.png')
# (363, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-87.png')
# (364, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-88.png')
# (365, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-89.png')
# (366, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-90.png')
# (367, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-91.png')
# (368, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-92.png')
# (369, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-93.png')
# (370, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-94.png')
# (371, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-95.png')
# (372, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-96.png')
# (373, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-97.png')
# (374, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-98.png')
# (375, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-99.png')
# (376, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-100.png')
# (377, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-101.png')
# (378, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-102.png')
# (379, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-103.png')
# (380, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-104.png')
# (381, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-105.png')
# (382, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-106.png')
# (383, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-107.png')
# (384, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-108.png')
# (385, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-109.png')
# (386, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-110.png')
# (387, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-111.png')
# (388, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-112.png')
# (389, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-113.png')
# (390, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-114.png')
# (391, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-115.png')
# (392, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-116.png')
# (393, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-117.png')
# (394, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-118.png')
# (395, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-119.png')
# (396, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-120.png')
# (397, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-121.png')
# (398, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-122.png')
# (399, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-123.png')
# (400, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-124.png')
# (401, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-125.png')
# (402, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-126.png')
# (403, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-127.png')
# (404, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-128.png')
# (405, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-129.png')
# (406, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-130.png')
# (407, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-131.png')
# (408, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-132.png')
# (409, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-133.png')
# (410, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-134.png')
# (411, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-135.png')
# (412, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-136.png')
# (413, 'green', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/green/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-137.png')
# (414, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-0.png')
# (415, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-1.png')
# (416, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-2.png')
# (417, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-3.png')
# (418, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-4.png')
# (419, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-5.png')
# (420, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-6.png')
# (421, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-7.png')
# (422, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-8.png')
# (423, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-9.png')
# (424, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-10.png')
# (425, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-11.png')
# (426, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-12.png')
# (427, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-13.png')
# (428, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-14.png')
# (429, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-15.png')
# (430, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-16.png')
# (431, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-17.png')
# (432, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-18.png')
# (433, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-19.png')
# (434, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-20.png')
# (435, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-21.png')
# (436, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-22.png')
# (437, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-23.png')
# (438, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-24.png')
# (439, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-25.png')
# (440, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-26.png')
# (441, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-27.png')
# (442, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-28.png')
# (443, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-29.png')
# (444, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-30.png')
# (445, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-31.png')
# (446, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-32.png')
# (447, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-33.png')
# (448, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-34.png')
# (449, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-35.png')
# (450, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-36.png')
# (451, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-37.png')
# (452, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-38.png')
# (453, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-39.png')
# (454, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-40.png')
# (455, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-41.png')
# (456, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-42.png')
# (457, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-43.png')
# (458, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-44.png')
# (459, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-45.png')
# (460, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-46.png')
# (461, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-47.png')
# (462, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-48.png')
# (463, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-49.png')
# (464, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-50.png')
# (465, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-51.png')
# (466, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-52.png')
# (467, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-53.png')
# (468, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-54.png')
# (469, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-55.png')
# (470, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-56.png')
# (471, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-57.png')
# (472, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-58.png')
# (473, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-59.png')
# (474, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-60.png')
# (475, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-61.png')
# (476, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-62.png')
# (477, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-63.png')
# (478, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-64.png')
# (479, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-65.png')
# (480, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-66.png')
# (481, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-67.png')
# (482, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-68.png')
# (483, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-69.png')
# (484, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-70.png')
# (485, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-71.png')
# (486, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-72.png')
# (487, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-73.png')
# (488, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-74.png')
# (489, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-75.png')
# (490, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-76.png')
# (491, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-77.png')
# (492, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-78.png')
# (493, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-79.png')
# (494, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-80.png')
# (495, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-81.png')
# (496, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-82.png')
# (497, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-83.png')
# (498, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-84.png')
# (499, 'cyan', '6.7FRhcrtR-Gal4-uasKaede', 'images/3-ColorChannels/6.7FRhcrtR-Gal4-uasKaede/cyan/6.7FRhcrtR-Gal4-uasKaede_6dpf_MeanImageOf12Fish-85.png')
